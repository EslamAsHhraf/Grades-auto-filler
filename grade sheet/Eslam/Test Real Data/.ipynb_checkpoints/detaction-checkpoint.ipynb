# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import interpolation as inter
from skimage.filters import gaussian
from scipy.signal import convolve2d
from contour_sort import *
from fix_image_orientation import *
from crop_image import *
from paper_extraction import *
from commonfunctions import *
from skimage.feature import canny
from skimage.morphology import binary_erosion, binary_dilation, binary_closing,skeletonize, thin
import os
from imutils import contours as imcnts

# %%
img = cv2.imread('../../Results/Results/2/4/1.jpg')
#img = cv2.imread('./100470.png')

# %%
show_images([img], ['original'])

# %%
colors=[(255,0,0)
,(0,255,0)
,(0,0,255)
,(255,255,192)
,(0,128,128)
,(255,215,0)
,(255,0,0)
,(0,255,0)
,(0,0,255)
,(0,255,0)
,(255,0,0)

,(225,255,128)
,(128,0,0)
,(128,128,0)
,(0,128,0)
,(128,0,128)

,(0,0,128)
,(255,215,0)]

# %%
def detect_check_mark(num):
    img = cv2.imread(f'../../../temp for me/{num}')
    temp=np.zeros_like(img)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img=cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
             cv2.THRESH_BINARY_INV, 51, 15)
    img=skeletonize(img,method='lee')
    
    # Filter Question Mark
    is_question_mark = cv2.HoughLinesP(img,1,np.pi/300,threshold=25,maxLineGap=15)
    if(is_question_mark is None):
        #print(f'{num} Failed With Filter Question Mark')
        return False
    
    # Filter Squares
    pap_cnts,_=cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    check_mark_cnts,_=imcnts.sort_contours(pap_cnts,method='top-to-bottom')
    cnt = check_mark_cnts[0]
    peri = cv2.arcLength(cnt, True)
    check_mark_cnt_area=cv2.contourArea(cnt)
    if(check_mark_cnt_area>1.5*peri):
        #print(f'{num} Failed With Filter Squares')
        return False
    
    
    lines = cv2.HoughLinesP(img,1,np.pi/300,threshold=4,maxLineGap=20)
    slopes=[]
    for index,line  in enumerate(lines):
        for x1, y1, x2, y2 in line:
            slopes.append((y2-y1)/(x2-x1))
            temp=cv2.line(temp,(x1,y1),(x2,y2),colors[index%len(colors)],1)
    slopes=np.sort(np.degrees(np.arctan(slopes)))
    ver_error=(slopes>=-90) & (slopes<=-83)
    slopes[ver_error]*=-1
    pos_ang=slopes[slopes>0]
    neg_ang=np.abs(slopes[slopes<0])
#     show_images([img], ['original'])
#     show_images([temp], ['temp'])

    # Filter Check Mark
    if(not len(pos_ang) or not len(neg_ang)):
        if(len(slopes)<2):
            #print(f'{num} Failed With Filter Check Marks')
            return False
        right_line = np.amax(slopes)
        left_line = np.amin(slopes)
        diff_ang=right_line-left_line 
        return diff_ang>20 and diff_ang<100
    else:
        right_line = np.mean(neg_ang) if len(neg_ang)<=2 else np.median(neg_ang) 
        left_line = np.mean(pos_ang) if len(pos_ang)<=2 else np.median(pos_ang)
        diff_ang=left_line+right_line 
        return diff_ang>80 and diff_ang<160

# %%
path='../../../temp for me/'
dir_list = os.listdir(path)
for name in dir_list:
    print(name,detect_check_mark(name))
# Out:
# check mark (1).jpg True
# check mark (10).jpg True
# check mark (11).jpg True
# check mark (12).jpg True
# check mark (13).jpg True
# check mark (14).jpg True
# check mark (15).jpg True
# check mark (16).jpg True
# check mark (17).jpg True
# check mark (2).jpg True
# check mark (3).jpg True
# check mark (4).jpg True
# check mark (5).jpg True
# check mark (6).jpg True
# check mark (7).jpg True
# check mark (8).jpg True
# check mark (9).jpg True
# check mark 2 (1).jpg True
# check mark 2 (10).jpg True
# check mark 2 (11).jpg True
# check mark 2 (12).jpg True
# check mark 2 (14).jpg True
# check mark 2 (15).jpg True
# check mark 2 (16).jpg True
# check mark 2 (17).jpg True
# check mark 2 (18).jpg True
# check mark 2 (2).jpg True
# check mark 2 (3).jpg True
# check mark 2 (4).jpg True
# check mark 2 (5).jpg True
# check mark 2 (6).jpg True
# check mark 2 (7).jpg True
# check mark 2 (8).jpg True
# check mark 2 (9).jpg True
# check mark error (1).jpg True
# check mark error (2).jpg True
# check mark error (3).jpg True
# question mark (1).jpg False
# question mark (10).jpg False
# question mark (11).jpg False
# question mark (12).jpg False
# question mark (13).jpg False
# question mark (14).jpg False
# question mark (15).jpg False
# question mark (16).jpg False
# question mark (17).jpg False
# question mark (18).jpg False
# question mark (2).jpg False
# question mark (3).jpg False
# question mark (4).jpg False
# question mark (5).jpg False
# question mark (6).jpg False
# question mark (7).jpg False
# question mark (8).jpg False
# question mark (9).jpg False
# square (1).jpg False
# square (10).jpg False
# square (11).jpg False
# square (12).jpg False
# square (13).jpg True
# square (14).jpg False
# square (15).jpg True
# square (16).jpg False
# square (17).jpg False
# square (2).jpg False
# square (3).jpg False
# square (4).jpg False
# square (5).jpg False
# square (6).jpg False
# square (7).jpg False
# square (8).jpg False
# square (9).jpg False
# vertical w horizontal (1).jpg False
# vertical w horizontal (10).jpg False
# vertical w horizontal (11).jpg False
# vertical w horizontal (12).jpg False
# vertical w horizontal (13).jpg False
# vertical w horizontal (14).jpg False
# vertical w horizontal (15).jpg False
# vertical w horizontal (16).jpg False
# vertical w horizontal (17).jpg False
# vertical w horizontal (18).jpg False
# vertical w horizontal (2).jpg False
# vertical w horizontal (3).jpg False
# vertical w horizontal (4).jpg False
# vertical w horizontal (5).jpg True
# vertical w horizontal (7).jpg False
# vertical w horizontal (8).jpg False
# vertical w horizontal (9).jpg False
# C:\Users\adham ali\AppData\Local\Temp\ipykernel_7108\156121247.py:30: RuntimeWarning: invalid value encountered in int_scalars
#   slopes.append((y2-y1)/(x2-x1))
# C:\Users\adham ali\AppData\Local\Temp\ipykernel_7108\156121247.py:30: RuntimeWarning: divide by zero encountered in int_scalars
#   slopes.append((y2-y1)/(x2-x1))
